# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/Economy_of_India')
India=df[2]
India
# Out:
#     Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0   1980                 371.9                        532.0
# 1   1981                 431.5                        603.2
# 2   1982                 474.1                        647.5
# 3   1983                 528.6                        705.3
# 4   1984                 568.6                        741.4
# 5   1985                 617.4                        787.1
# 6   1986                 659.9                        822.8
# 7   1987                 703.0                        857.7
# 8   1988                 797.9                        952.7
# 9   1989                 878.5                       1027.0
# 10  1990                 961.8                       1101.3
# 11  1991                1004.8                       1127.4
# 12  1992                1084.1                       1192.2
# 13  1993                1162.5                       1253.5
# 14  1994                1266.4                       1339.2
# ...

# %%
India.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             48 non-null     int64
#  1   GDP (in Bil. US$PPP)             48 non-null     float64
#  2   GDP per capita (in US$ PPP)      48 non-null     float64
#  3   GDP (in Bil. US$nominal)         48 non-null     float64
#  4   GDP per capita (in US$ nominal)  48 non-null     float64
#  5   GDP growth (real)                48 non-null     object
#  6   Inflation rate (in Percent)      48 non-null     object
#  7   Unemployment (in Percent)        31 non-null     object
#  8   Government debt (in % of GDP)    37 non-null     object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 3.5+ KB

# %%
India['Country']='India'

# %%
India.head()
# Out:
#    Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0  1980                 371.9                        532.0
# 1  1981                 431.5                        603.2
# 2  1982                 474.1                        647.5
# 3  1983                 528.6                        705.3
# 4  1984                 568.6                        741.4
#
#    GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                     189.4                            271.0
# 1                     196.5                            274.7
# 2                     203.5                            278.0
# 3                     222.0                            296.3
# 4                     215.6                            281.1
#
#   GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 0              5.3%                       11.3%                       NaN
# 1              6.0%                       12.7%                       NaN
# ...

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/Economy_of_the_United_States')
US=df[3]
US
# Out:
#     Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0   1980                2857.3                      12552.9
# 1   1981                3207.0                      13948.7
# 2   1982                3343.8                      14405.0
# 3   1983                3634.0                      15513.7
# 4   1984                4037.7                      17086.4
# 5   1985                4339.0                      18199.3
# 6   1986                4579.6                      19034.8
# 7   1987                4855.3                      20001.0
# 8   1988                5236.4                      21376.0
# 9   1989                5641.6                      22814.1
# 10  1990                5963.1                      23848.0
# 11  1991                6158.1                      24302.8
# 12  1992                6520.3                      25392.9
# 13  1993                6858.6                      26364.2
# 14  1994                7287.3                      27674.0
# ...

# %%
US['Country']='US'
US.head()
# Out:
#    Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0  1980                2857.3                      12552.9
# 1  1981                3207.0                      13948.7
# 2  1982                3343.8                      14405.0
# 3  1983                3634.0                      15513.7
# 4  1984                4037.7                      17086.4
#
#    GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                    2857.3                          12552.9
# 1                    3207.0                          13948.7
# 2                    3343.8                          14405.0
# 3                    3634.0                          15513.7
# 4                    4037.7                          17086.4
#
#   GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 0             -0.3%                       13.5%                      7.2%
# 1              2.5%                       10.4%                      7.6%
# ...

# %%
US.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             48 non-null     int64
#  1   GDP (in Bil. US$PPP)             48 non-null     float64
#  2   GDP per capita (in US$ PPP)      48 non-null     float64
#  3   GDP (in Bil. US$nominal)         48 non-null     float64
#  4   GDP per capita (in US$ nominal)  48 non-null     float64
#  5   GDP growth (real)                48 non-null     object
#  6   Inflation rate (in Percent)      48 non-null     object
#  7   Unemployment (in Percent)        48 non-null     object
#  8   Government debt (in % of GDP)    27 non-null     object
#  9   Country                          48 non-null     object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.9+ KB

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/Economy_of_China')
China=df[3]
China
# Out:
#     Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0   1980                 302.8                        306.7
# 1   1981                 348.3                        348.1
# 2   1982                 403.1                        396.6
# 3   1983                 464.1                        450.6
# 4   1984                 554.0                        530.9
# 5   1985                 648.7                        612.8
# 6   1986                 718.6                        668.4
# 7   1987                 822.5                        752.6
# 8   1988                 946.9                        852.9
# 9   1989                1025.4                        909.8
# 10  1990                1105.1                        966.6
# 11  1991                1248.7                       1078.1
# 12  1992                1459.6                       1245.7
# 13  1993                1701.5                       1435.7
# 14  1994                1964.3                       1639.0
# ...

# %%
China['Country']='China'
China.head()
# Out:
#    Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0  1980                 302.8                        306.7
# 1  1981                 348.3                        348.1
# 2  1982                 403.1                        396.6
# 3  1983                 464.1                        450.6
# 4  1984                 554.0                        530.9
#
#    GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                     303.0                            307.0
# 1                     288.7                            288.5
# 2                     284.6                            280.0
# 3                     305.4                            296.5
# 4                     314.2                            301.1
#
#   GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 0              7.9%                         NaN                      4.9%
# 1              5.1%                        2.5%                      3.8%
# ...

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/Economy_of_Japan')
Japan=df[7]
Japan
# Out:
#     Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0   1980                1068.1                       9147.0
# 1   1981                1218.4                      10358.1
# 2   1982                1336.5                      11283.0
# 3   1983                1437.8                      12054.5
# 4   1984                1556.7                      12967.1
# 5   1985                1690.0                      13989.8
# 6   1986                1781.4                      14667.9
# 7   1987                1911.8                      15666.3
# 8   1988                2113.5                      17246.0
# 9   1989                2303.0                      18719.6
# 10  1990                2506.1                      20302.7
# 11  1991                2679.4                      21620.8
# 12  1992                2763.7                      22222.4
# 13  1993                2814.6                      22558.2
# 14  1994                2899.9                      23177.4
# ...

# %%
Japan['Country']='Japan'
Japan.head()
# Out:
#    Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0  1980                1068.1                       9147.0
# 1  1981                1218.4                      10358.1
# 2  1982                1336.5                      11283.0
# 3  1983                1437.8                      12054.5
# 4  1984                1556.7                      12967.1
#
#    GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                    1127.9                           9659.0
# 1                    1243.8                          10574.4
# 2                    1157.6                           9772.8
# 3                    1268.6                          10636.5
# 4                    1345.2                          11205.4
#
#   GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 0              3.2%                        7.8%                      2.0%
# 1              4.2%                        4.9%                      2.2%
# ...

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/Economy_of_Germany')
Germany=df[1]
Germany
# Out:
#     Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0   1980                 855.3                      11130.4
# 1   1981                 937.2                      12174.0
# 2   1982                 987.3                      12833.5
# 3   1983                1041.9                      13590.8
# 4   1984                1110.0                      14537.9
# 5   1985                1170.2                      15364.3
# 6   1986                1222.7                      16041.5
# 7   1987                1271.3                      16676.8
# 8   1988                1365.3                      17801.4
# 9   1989                1474.4                      19033.2
# 10  1990                1617.1                      20482.9
# 11  1991                1755.6                      21951.9
# 12  1992                1830.0                      22733.4
# 13  1993                1855.1                      22917.9
# 14  1994                1940.2                      23909.4
# ...

# %%
Germany['Country']='Germany'
Germany.head()
# Out:
#    Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0  1980                 855.3                      11130.4
# 1  1981                 937.2                      12174.0
# 2  1982                 987.3                      12833.5
# 3  1983                1041.9                      13590.8
# 4  1984                1110.0                      14537.9
#
#    GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                     853.7                          11109.7
# 1                     718.3                           9329.6
# 2                     693.5                           9015.0
# 3                     691.9                           9025.2
# 4                     651.9                           8537.8
#
#   GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 0              1.3%                        5.4%                      3.4%
# 1              0.1%                        6.3%                      4.8%
# ...

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/Economy_of_the_United_Kingdom')
UK=df[10]
UK
# Out:
#     Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0   1980                 511.8                       9085.1
# 1   1981                 556.3                       9870.7
# 2   1982                 602.3                      10699.9
# 3   1983                 652.2                      11580.6
# 4   1984                 690.9                      12247.2
# 5   1985                 742.1                      13121.9
# 6   1986                 780.9                      13776.7
# 7   1987                 843.4                      14847.8
# 8   1988                 922.1                      16200.4
# 9   1989                 981.6                      17198.6
# 10  1990                1024.8                      17904.8
# 11  1991                1046.9                      18226.8
# 12  1992                1074.1                      18653.1
# 13  1993                1126.0                      19509.9
# 14  1994                1193.4                      20624.6
# ...

# %%
UK['Country']='UK'
UK.head()
# Out:
#    Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0  1980                 511.8                       9085.1
# 1  1981                 556.3                       9870.7
# 2  1982                 602.3                      10699.9
# 3  1983                 652.2                      11580.6
# 4  1984                 690.9                      12247.2
#
#    GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                     603.6                          10715.4
# 1                     587.3                          10420.4
# 2                     558.3                           9918.9
# 3                     532.1                           9448.7
# 4                     504.2                           8938.7
#
#   GDP growth (real) Inflation rate (in %) Unemployment (in %)  \
# 0             -2.1%                 16.8%                7.1%
# 1             -0.7%                 12.2%                9.7%
# ...

# %%
UK.columns
# Out:
# Index(['Year', 'GDP (in Bil. US$PPP)', 'GDP per capita (in US$ PPP)',
#        'GDP (in Bil. US$nominal)', 'GDP per capita (in US$ nominal)',
#        'GDP growth (real)', 'Inflation rate (in %)', 'Unemployment (in %)',
#        'Government debt (in % of GDP)', 'Country'],
#       dtype='object')

# %%
final.columns
# Out:
# Index(['Year', 'GDP (in Bil. US$PPP)', 'GDP per capita (in US$ PPP)',
#        'GDP (in Bil. US$nominal)', 'GDP per capita (in US$ nominal)',
#        'GDP growth (real)', 'Inflation rate (in Percent)',
#        'Unemployment (in Percent)', 'Government debt (in % of GDP)',
#        'Country'],
#       dtype='object')

# %%
UK.rename(columns={'Inflation rate (in %)':'Inflation rate (in Percent)','Unemployment (in %)':'Unemployment (in Percent)'},inplace=True)
UK.head()
# Out:
#    Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0  1980                 511.8                       9085.1
# 1  1981                 556.3                       9870.7
# 2  1982                 602.3                      10699.9
# 3  1983                 652.2                      11580.6
# 4  1984                 690.9                      12247.2
#
#    GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                     603.6                          10715.4
# 1                     587.3                          10420.4
# 2                     558.3                           9918.9
# 3                     532.1                           9448.7
# 4                     504.2                           8938.7
#
#   GDP growth (real) Inflation rate (in %) Unemployment (in %)  \
# 0             -2.1%                 16.8%                7.1%
# 1             -0.7%                 12.2%                9.7%
# ...

# %%
final=pd.concat([US,China],ignore_index=True)
final.tail()
# Out:
#     Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 91  2023               32529.2                      23038.3
# 92  2024               34705.7                      24599.3
# 93  2025               36988.5                      26248.0
# 94  2026               39427.3                      28022.1
# 95  2027               42050.2                      29943.8
#
#     GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 91                   19244.0                          13629.3
# 92                   20699.1                          14671.5
# 93                   22404.0                          15898.5
# 94                   24295.4                          17267.4
# 95                   26437.7                          18826.2
#
#    GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 91              4.4%                        2.2%                      4.1%
# 92              4.5%                        1.9%                      3.9%
# ...

# %%
final.head()
# Out:
#    Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0  1980                2857.3                      12552.9
# 1  1981                3207.0                      13948.7
# 2  1982                3343.8                      14405.0
# 3  1983                3634.0                      15513.7
# 4  1984                4037.7                      17086.4
#
#    GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                    2857.3                          12552.9
# 1                    3207.0                          13948.7
# 2                    3343.8                          14405.0
# 3                    3634.0                          15513.7
# 4                    4037.7                          17086.4
#
#   GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 0             -0.3%                       13.5%                      7.2%
# 1              2.5%                       10.4%                      7.6%
# ...

# %%
final=pd.concat([final,Japan],ignore_index=True)
final.tail()
# Out:
#      Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 139  2023                6429.7                      51594.1
# 140  2024                6652.7                      53633.3
# 141  2025                6839.5                      55411.7
# 142  2026                7002.5                      57025.8
# 143  2027                7167.5                      58684.7
#
#      GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 139                    4366.0                          35033.9
# 140                    4568.7                          36832.8
# 141                    4811.6                          38982.7
# 142                    5010.0                          40799.8
# 143                    5172.1                          42347.0
#
#     GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 139              1.6%                        1.4%                      2.4%
# ...

# %%
final=pd.concat([final,Germany],ignore_index=True)
final.tail()
# Out:
#      Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 187  2023                5490.2                      65865.3
# 188  2024                5689.6                      68235.1
# 189  2025                5920.6                      71011.2
# 190  2026                6143.0                      73716.8
# 191  2027                6346.0                      76204.6
#
#      GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 187                    4120.2                          49430.1
# 188                    4337.4                          52017.6
# 189                    4546.5                          54530.9
# 190                    4740.7                          56889.6
# 191                    4925.0                          59140.7
#
#     GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 187             -0.3%                        7.2%                      3.4%
# ...

# %%
final=pd.concat([final,India],ignore_index=True)
final.tail()
# Out:
#      Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 235  2023               13033.4                       9073.0
# 236  2024               14165.5                       9773.0
# 237  2025               15330.6                      10484.8
# 238  2026               16563.8                      11232.6
# 239  2027               17877.0                      12024.0
#
#      GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 235                    3820.6                           2691.2
# 236                    4170.2                           2911.2
# 237                    4547.2                           3146.8
# 238                    4947.4                           3394.9
# 239                    5365.5                           3651.7
#
#     GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 235              6.1%                        5.1%                       NaN
# ...

# %%
final.shape
# Out:
# (240, 10)

# %%
final
# Out:
#      Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0    1980                2857.3                      12552.9
# 1    1981                3207.0                      13948.7
# 2    1982                3343.8                      14405.0
# 3    1983                3634.0                      15513.7
# 4    1984                4037.7                      17086.4
# ..    ...                   ...                          ...
# 235  2023               13033.4                       9073.0
# 236  2024               14165.5                       9773.0
# 237  2025               15330.6                      10484.8
# 238  2026               16563.8                      11232.6
# 239  2027               17877.0                      12024.0
#
#      GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                      2857.3                          12552.9
# 1                      3207.0                          13948.7
# ...

# %%
final.sample(40)
# Out:
#      Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 178  2014                3807.1                      47011.1
# 155  1991                1755.6                      21951.9
# 152  1988                1365.3                      17801.4
# 230  2018                9023.0                       6590.9
# 89   2021               27206.1                      19259.6
# 192  1980                 371.9                        532.0
# 229  2017                8276.9                       6182.9
# 159  1995                2011.4                      24738.0
# 170  2006                2956.3                      36419.4
# 34   2014               17550.7                      55083.5
# 183  2019                4692.1                      56468.0
# 202  1990                 961.8                       1101.3
# 189  2025                5920.6                      71011.2
# 181  2017                4411.7                      53373.9
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             240 non-null    int64
#  1   GDP (in Bil. US$PPP)             240 non-null    float64
#  2   GDP per capita (in US$ PPP)      240 non-null    float64
#  3   GDP (in Bil. US$nominal)         240 non-null    float64
#  4   GDP per capita (in US$ nominal)  240 non-null    float64
#  5   GDP growth (real)                240 non-null    object
#  6   Inflation rate (in Percent)      239 non-null    object
#  7   Unemployment (in Percent)        223 non-null    object
#  8   Government debt (in % of GDP)    182 non-null    object
#  9   Country                          240 non-null    object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 18.9+ KB

# %%
final.to_csv("Top countries GDP info")
